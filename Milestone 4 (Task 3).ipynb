# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# > We need pandas and matplotlib for the task. Pandas is a library to manupulate data. Matplotlib is package to visualize data. Pyplot is the interface for Matplotlib

# %%
pwd
# Out:
# '/home/thanu/Desktop/mendicantbias'

# %%
df= pd.read_csv(r"/home/thanu/Desktop/mendicantbias/src/bitcoin.csv")

df["date"] = pd.to_datetime(df["Timestamp"], unit="s").dt.date
group = df.groupby('date')

# %% [markdown]
# > We tried to use the data (group) to plot, but it did not work. But  we provide both datas for this task. We are not sure, but we think the changes made in datetime could have lead to sum issues.

# %%
df.head()
# Out:
#     Timestamp   Open   High    Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1417411980  300.0  300.0  300.0  300.0          0.01                3.0
# 1  1417412040  300.0  300.0  300.0  300.0          0.01                3.0
# 2  1417412100  300.0  300.0  300.0  300.0          0.01                3.0
# 3  1417412160  300.0  300.0  300.0  300.0          0.01                3.0
# 4  1417412220  300.0  300.0  300.0  300.0          0.01                3.0
#
#    Weighted_Price        date
# 0           300.0  2014-12-01
# 1           300.0  2014-12-01
# 2           300.0  2014-12-01
# 3           300.0  2014-12-01
# 4           300.0  2014-12-01

# %% [markdown]
# > With the commands head and tail, have a first look at the data (inspection)

# %%
group.head()
# Out:
#        Timestamp    Open    High     Low   Close  Volume_(BTC)  \
# 0     1417411980  300.00  300.00  300.00  300.00      0.010000
# 1     1417412040  300.00  300.00  300.00  300.00      0.010000
# 2     1417412100  300.00  300.00  300.00  300.00      0.010000
# 3     1417412160  300.00  300.00  300.00  300.00      0.010000
# 4     1417412220  300.00  300.00  300.00  300.00      0.010000
# 1107  1417478400  370.00  370.00  370.00  370.00      0.026556
# 1108  1417478460  370.00  370.00  370.00  370.00      0.026556
# 1109  1417478520  370.00  370.00  370.00  370.00      0.026556
# 1110  1417478580  370.00  370.00  370.00  370.00      0.026556
# 1111  1417478640  370.00  370.00  370.00  370.00      0.026556
# 2547  1417564800  378.00  378.00  378.00  378.00      0.010000
# 2548  1417564860  378.00  378.00  378.00  378.00      0.010000
# 2549  1417564920  378.00  378.00  378.00  378.00      0.010000
# 2550  1417564980  378.00  378.00  378.00  378.00      0.010000
# ...

# %% [markdown]
# >The table above shows the first entry for every group (sorted by date).

# %%
df.describe()
# Out:
#           Timestamp          Open          High           Low         Close  \
# count  1.027500e+04  10275.000000  10275.000000  10275.000000  10275.000000
# mean   1.419714e+09    278.644326    280.306878    275.802969    277.246748
# std    1.788394e+06     88.453580     86.894732     91.811155     90.642619
# min    1.417412e+09    109.870000    109.940000    109.870000    109.940000
# 25%    1.417566e+09    189.000000    189.130000    189.000000    189.000000
# 50%    1.420741e+09    284.350000    289.250000    273.550000    282.410000
# 75%    1.421267e+09    377.000000    377.000000    377.000000    377.000000
# max    1.421421e+09    398.000000    398.000000    398.000000    398.000000
#
#        Volume_(BTC)  Volume_(Currency)  Weighted_Price
# count  10275.000000       10275.000000    10275.000000
# mean       0.398345         131.050041      277.879212
# std        1.096373         407.636293       89.299344
# min        0.010000           1.099400      109.940000
# ...

# %% [markdown]
# >Above is the summary statistics for our data

# %%
group.describe()
# Out:
#            Timestamp                                                          \
#                count          mean           std           min           25%
# date
# 2014-12-01    1107.0  1.417445e+09  19182.460739  1.417412e+09  1.417429e+09
# 2014-12-02    1440.0  1.417522e+09  24950.190380  1.417478e+09  1.417500e+09
# 2014-12-03    1440.0  1.417608e+09  24950.190380  1.417565e+09  1.417586e+09
# 2014-12-04     109.0  1.417654e+09   1896.575862  1.417651e+09  1.417653e+09
# 2014-12-06       1.0  1.417830e+09           NaN  1.417830e+09  1.417830e+09
# 2014-12-08       1.0  1.418078e+09           NaN  1.418078e+09  1.418078e+09
# 2014-12-10       2.0  1.418179e+09     42.426407  1.418179e+09  1.418179e+09
# 2014-12-12      17.0  1.418355e+09    302.985148  1.418355e+09  1.418355e+09
# 2014-12-18       1.0  1.418936e+09           NaN  1.418936e+09  1.418936e+09
# 2015-01-08    1136.0  1.420714e+09  19684.755523  1.420680e+09  1.420697e+09
# ...

# %%
plt.hist(x= df["Weighted_Price"])
plt.show()

# %% [markdown]
# >The graph (histogram) above shows the nummer of oberservations for the given level of weighted price.

# %%
plt.plot(x= group["Weighted_Price"])
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-b60316370157> in <module>
# ----> 1 plt.plot(x= group["Weighted_Price"])
#       2 plt.show
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# ...

# %% [markdown]
# >We were not able to plot using the data, which was grouped by the dates.
